# %%
import pandas as pd

# %%
df = pd.read_csv('balance.txt', sep=' ')

# %% [markdown]
# Write the code needed to produce a report that provides the following information:
# * Compare the average income based on ethnicity.
# * On average, do married or single people have a higher balance?
# * What is the highest income in our dataset?
# * What is the lowest income in our dataset?
# * How many cards do we have recorded in our dataset? (Hint: use `sum()`)
# * How many females do we have information for vs how many males? (Hint: use `count()` for a list of all methods for computation of descriptive stats, explore the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats)).

# %%
# Compare the average income based on ethnicity.
from statistics import mean
grouped = df.groupby('Ethnicity')
print(df.groupby("Ethnicity")['Income'].mean())
# Out:
# Ethnicity
# African American    47.682101
# Asian               44.187833
# Caucasian           44.521945
# Name: Income, dtype: float64

# %%
# On average, do married or single people have a higher balance?
df.groupby('Married')
print(df.groupby("Married")['Balance'].mean())
# Out:
# Married
# No     13.493509
# Yes    13.388473
# Name: Balance, dtype: float64

# %%
# What is the highest income in our dataset?
df.sort_values(by= "Income", ascending=False).head(1)
# Out:
#       Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 28  35.271011  186.634  13414     949      2   41         14  Female      No
#
#    Married         Ethnicity
# 28     Yes  African American

# %%
# What is the lowest income in our dataset?
df.sort_values(by= "Income", ascending=False).tail(1)
# Out:
#      Balance  Income  Limit  Rating  Cards  Age  Education Gender Student  \
# 58  9.180797  10.354   3480     281      2   70         17   Male      No
#
#    Married  Ethnicity
# 58     Yes  Caucasian

# %%
# How many cards do we have recorded in our dataset? (Hint: use `sum()`)
cols = ['Cards']
df[cols].sum()
# Out:
# Cards    1183
# dtype: int64

# %%
# How many females do we have information for vs how many males?
cols = ['Gender']
grouped = df[cols].groupby('Gender')
Female = grouped.get_group('Female').value_counts()
Male = grouped.get_group('Male').value_counts()
print(f"There are {Male} males and {Female} females in the data frame.")
# Out:
# There are Gender
# Male      193
# Name: count, dtype: int64 males and Gender
# Female    207
# Name: count, dtype: int64 females in the data frame.
